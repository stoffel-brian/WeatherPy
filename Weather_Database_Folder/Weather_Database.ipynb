# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import Random module
import random


# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Use the tuple() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
#    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)



# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | shchors
# Processing Record 3 of Set 1 | qom
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | adrar
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 1 | baglung
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | alice springs
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 1 | bonavista
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | carlyle
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | ballina
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | taft
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | nimaparha
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | guntur
# Processing Record 34 of Set 1 | qui nhon
# Processing Record 35 of Set 1 | irbit
# Processing Record 36 of Set 1 | puerto carreno
# Processing Record 37 of Set 1 | boston
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | mahmudabad
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | swan hill
# Processing Record 44 of Set 1 | salalah
# Processing Record 45 of Set 1 | carballo
# Processing Record 46 of Set 1 | kavieng
# Processing Record 47 of Set 1 | wakema
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | bima
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | wampusirpi
# City not found. Skipping...
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | aras
# Processing Record 7 of Set 2 | gouloure
# Processing Record 8 of Set 2 | boende
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | vestmannaeyjar
# Processing Record 11 of Set 2 | san gabriel
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | bilma
# Processing Record 16 of Set 2 | tamandare
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | atasu
# Processing Record 22 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | tankara
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | poum
# Processing Record 32 of Set 2 | syamzha
# Processing Record 33 of Set 2 | omboue
# Processing Record 34 of Set 2 | durango
# Processing Record 35 of Set 2 | koslan
# Processing Record 36 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | goderich
# Processing Record 40 of Set 2 | forquilhinha
# Processing Record 41 of Set 2 | almeria
# Processing Record 42 of Set 2 | shache
# Processing Record 43 of Set 2 | tingrela
# City not found. Skipping...
# Processing Record 44 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | porto walter
# Processing Record 47 of Set 2 | xining
# Processing Record 48 of Set 2 | puerto escondido
# Processing Record 49 of Set 2 | muros
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | kenai
# Processing Record 2 of Set 3 | kolokani
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | praia da vitoria
# Processing Record 5 of Set 3 | richards bay
# Processing Record 6 of Set 3 | vilyuysk
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | marzuq
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | sukhumi
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 3 | biak
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | lorengau
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 21 of Set 3 | barreirinhas
# Processing Record 22 of Set 3 | cape town
# Processing Record 23 of Set 3 | guerrero negro
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | victor harbor
# Processing Record 26 of Set 3 | lonigo
# Processing Record 27 of Set 3 | bandarbeyla
# Processing Record 28 of Set 3 | dubrovka
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | penzance
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | ituiutaba
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | ahome
# Processing Record 36 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 3 | panaba
# Processing Record 38 of Set 3 | saint-joseph
# Processing Record 39 of Set 3 | acarau
# Processing Record 40 of Set 3 | thompson
# Processing Record 41 of Set 3 | pecanha
# Processing Record 42 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 3 | coahuayana
# Processing Record 44 of Set 3 | bilibino
# Processing Record 45 of Set 3 | kimberley
# Processing Record 46 of Set 3 | plouzane
# Processing Record 47 of Set 3 | saint-philippe
# Processing Record 48 of Set 3 | pulawy
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | hare bay

# %%
#df = pd.DataFrame(list with dictionaries)

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#new_column_order = ["column2", "column4", "column1"]
#df = df[new_column_order]
print(city_data_df)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Leningradskiy  69.3833  178.4167     -8.79        91          31
# 1             Aras  42.5617   -2.3560     45.01        85          40
# 2     Vysokogornyy  50.1167  139.1500     26.17        83          60
# 3          Mataura -46.1927  168.8643     54.48        49          30
# 4      Clyde River  70.4692  -68.5914     21.56        86          97
# ..             ...      ...       ...       ...       ...         ...
# 661        Waipawa -41.4122  175.5153     51.46        71         100
# 662  Porto-Vecchio  41.5910    9.2795     62.13        82          90
# 663       Tianpeng  30.9866  103.9393     55.87        86          95
# 664     Carutapera  -1.1950  -46.0200     80.02        78         100
# 665       Barcelos  41.5388   -8.6151     52.84        83          55
#
#      Wind Speed Country                 Date
# 0          6.55      RU  2021-11-03 20:30:35
# 1         11.50      ES  2021-11-03 20:30:36
# 2          2.17      RU  2021-11-03 20:30:36
# 3          2.33      NZ  2021-11-03 20:30:36
# 4         32.21      CA  2021-11-03 20:30:37
# ..          ...     ...                  ...
# 661       14.45      NZ  2021-11-03 20:48:07
# 662       14.97      FR  2021-11-03 20:48:07
# 663        1.21      CN  2021-11-03 20:48:08
# 664        7.00      BR  2021-11-03 20:48:08
# 665        4.14      PT  2021-11-03 20:48:09
#
# [666 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
